# %% [markdown]
# <a href="https://colab.research.google.com/github/robertoarturomc/ProgramacionConcurrente/blob/main/2_Programaci%C3%B3n_Secuencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import time

# %%
data = pd.read_json('/content/sample_data/anscombe.json')

data.groupby('Series').mean()
# Out:
#   Series   X     Y
# 0      I  10  8.04
# 1      I   8  6.95
# 2      I  13  7.58
# 3      I   9  8.81
# 4      I  11  8.33

# %%
data.groupby('Series').std()
# Out:
#                X         Y
# Series
# I       3.316625  2.032890
# II      3.316625  2.031657
# III     3.316625  2.030424
# IV      3.316625  2.030579
